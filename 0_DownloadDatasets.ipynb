# %%
# !mkdir dataset
# !mkdir results
# !wget -nc --content-disposition https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/14 -P dataset # dichasus-cf02
# !wget -nc --content-disposition https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/15 -P dataset # dichasus-cf03
# !wget -nc --content-disposition https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/16 -P dataset # dichasus-cf04

# !wget -nc https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf02.json -P dataset
# !wget -nc https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf03.json -P dataset
# !wget -nc https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf04.json -P dataset

# !wget -nc --content-disposition https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/19 -P dataset # spec.json
# Out:
# --2024-09-12 09:27:03--  https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/14
# Resolving darus.uni-stuttgart.de (darus.uni-stuttgart.de)... 129.69.7.87, 2001:7c0:2041:17f::87
# Connecting to darus.uni-stuttgart.de (darus.uni-stuttgart.de)|129.69.7.87|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ecd5699d7-94a3d3279f39?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf02.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20240912T092703Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172799&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20240912%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=10f9a894980376042feb99a0474d0a606266c4142455dbaf68bfafd500fd16c2 [following]
# --2024-09-12 09:27:03--  https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ecd5699d7-94a3d3279f39?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf02.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20240912T092703Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172799&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20240912%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=10f9a894980376042feb99a0474d0a606266c4142455dbaf68bfafd500fd16c2
# Resolving s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)... 129.69.5.100, 129.69.5.99, 2001:7c0:2041:1db::100, ...
# Connecting to s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)|129.69.5.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4885294444 (4.5G) [application/octet-stream]
# Saving to: ‘dataset/dichasus-cf02.tfrecords’
#
# dichasus-cf02.tfrec 100%[===================>]   4.55G  50.8MB/s    in 1m 55s
#
# 2024-09-12 09:29:00 (40.4 MB/s) - ‘dataset/dichasus-cf02.tfrecords’ saved [4885294444/4885294444]
#
# --2024-09-12 09:29:00--  https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/15
# Resolving darus.uni-stuttgart.de (darus.uni-stuttgart.de)... 129.69.7.87, 2001:7c0:2041:17f::87
# Connecting to darus.uni-stuttgart.de (darus.uni-stuttgart.de)|129.69.7.87|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ecd5826ef-29891f50dfba?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf03.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20240912T092900Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172800&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20240912%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=a4dd5f621e9d2d2b378e79c4690e5c3e3e5ef5bde53fddc4f807692bb53b63fd [following]
# --2024-09-12 09:29:00--  https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ecd5826ef-29891f50dfba?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf03.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20240912T092900Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172800&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20240912%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=a4dd5f621e9d2d2b378e79c4690e5c3e3e5ef5bde53fddc4f807692bb53b63fd
# Resolving s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)... 129.69.5.99, 129.69.5.100, 2001:7c0:2041:1db::100, ...
# Connecting to s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)|129.69.5.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5946549946 (5.5G) [application/octet-stream]
# Saving to: ‘dataset/dichasus-cf03.tfrecords’
#
# dichasus-cf03.tfrec 100%[===================>]   5.54G  36.7MB/s    in 2m 46s
#
# 2024-09-12 09:31:47 (34.1 MB/s) - ‘dataset/dichasus-cf03.tfrecords’ saved [5946549946/5946549946]
#
# --2024-09-12 09:31:47--  https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/16
# Resolving darus.uni-stuttgart.de (darus.uni-stuttgart.de)... 129.69.7.87, 2001:7c0:2041:17f::87
# Connecting to darus.uni-stuttgart.de (darus.uni-stuttgart.de)|129.69.7.87|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ecd5b6fc0-63757420b35e?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf04.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20240912T093148Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172800&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20240912%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=a93ebf4991d8d064ed395ff83b84d12c4f97f2730cbe0e9e9b44f7e5d26d09fa [following]
# --2024-09-12 09:31:48--  https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ecd5b6fc0-63757420b35e?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf04.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20240912T093148Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172800&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20240912%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=a93ebf4991d8d064ed395ff83b84d12c4f97f2730cbe0e9e9b44f7e5d26d09fa
# Resolving s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)... 129.69.5.100, 129.69.5.99, 2001:7c0:2041:1db::100, ...
# Connecting to s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)|129.69.5.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11071618276 (10G) [application/octet-stream]
# Saving to: ‘dataset/dichasus-cf04.tfrecords’
#
# dichasus-cf04.tfrec 100%[===================>]  10.31G  54.9MB/s    in 4m 21s
#
# 2024-09-12 09:36:10 (40.5 MB/s) - ‘dataset/dichasus-cf04.tfrecords’ saved [11071618276/11071618276]
#
# --2024-09-12 09:36:10--  https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf02.json
# Resolving dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)... 129.69.175.114
# Connecting to dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)|129.69.175.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1833 (1.8K) [application/json]
# Saving to: ‘dataset/reftx-offsets-dichasus-cf02.json’
#
# reftx-offsets-dicha 100%[===================>]   1.79K  --.-KB/s    in 0s
#
# 2024-09-12 09:36:10 (152 MB/s) - ‘dataset/reftx-offsets-dichasus-cf02.json’ saved [1833/1833]
#
# --2024-09-12 09:36:10--  https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf03.json
# Resolving dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)... 129.69.175.114
# Connecting to dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)|129.69.175.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1834 (1.8K) [application/json]
# Saving to: ‘dataset/reftx-offsets-dichasus-cf03.json’
#
# reftx-offsets-dicha 100%[===================>]   1.79K  --.-KB/s    in 0s
#
# 2024-09-12 09:36:11 (170 MB/s) - ‘dataset/reftx-offsets-dichasus-cf03.json’ saved [1834/1834]
#
# --2024-09-12 09:36:11--  https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf04.json
# Resolving dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)... 129.69.175.114
# Connecting to dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)|129.69.175.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1841 (1.8K) [application/json]
# Saving to: ‘dataset/reftx-offsets-dichasus-cf04.json’
#
# reftx-offsets-dicha 100%[===================>]   1.80K  --.-KB/s    in 0s
#
# 2024-09-12 09:36:11 (80.2 MB/s) - ‘dataset/reftx-offsets-dichasus-cf04.json’ saved [1841/1841]
#
# --2024-09-12 09:36:11--  https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/19
# Resolving darus.uni-stuttgart.de (darus.uni-stuttgart.de)... 129.69.7.87, 2001:7c0:2041:17f::87
# Connecting to darus.uni-stuttgart.de (darus.uni-stuttgart.de)|129.69.7.87|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ed2590b69-8674fc020773?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27spec.json&response-content-type=application%2Fjson&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20240912T093611Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172800&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20240912%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=788037545a55383f3bd36c335195eb36315fc740117279bf363296fc0472e6f3 [following]
# --2024-09-12 09:36:11--  https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/18ed2590b69-8674fc020773?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27spec.json&response-content-type=application%2Fjson&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20240912T093611Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172800&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20240912%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=788037545a55383f3bd36c335195eb36315fc740117279bf363296fc0472e6f3
# Resolving s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)... 129.69.5.100, 129.69.5.99, 2001:7c0:2041:1db::100, ...
# Connecting to s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)|129.69.5.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4231 (4.1K) [application/json]
# Saving to: ‘dataset/spec.json’
#
# spec.json           100%[===================>]   4.13K  --.-KB/s    in 0s
#
# 2024-09-12 09:36:11 (1.75 GB/s) - ‘dataset/spec.json’ saved [4231/4231]
